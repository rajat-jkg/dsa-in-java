# %%
from requests import get

# %%
r = get('https://rajatgupta.me')

# %%
r.text
# Out:
# '<!DOCTYPE html>\r\n<html lang="en-US">\r\n<head>\r\n<meta charset="UTF-8">\r\n<meta name="viewport" content="width=device-width, initial-scale=1">\r\n<link rel="profile" href="https://gmpg.org/xfn/11">\r\n\r\n<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n\n\t<!-- This site is optimized with the Yoast SEO plugin v19.8 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>Rajat Gupta</title>\n\t<link rel="canonical" href="https://rajatgupta.me/" />\n\t<meta property="og:locale" content="en_US" />\n\t<meta property="og:type" content="website" />\n\t<meta property="og:title" content="Rajat Gupta" />\n\t<meta property="og:description" content="Rajat Gupta Hi, I am Rajat Gupta. I am a Web Developer, an SEO analyst and a graphic designer with more than 3 years of experience. I am also proficient with different programming languages. Know More What you can contact me for Web solutions SEO Design Consultation Let&#8217;s
# ...
